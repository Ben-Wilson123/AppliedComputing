# %% [markdown]
# # Lab 2 Write Up

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ##### MIR4461 was the most expressed gene in this dataset as displayed in both the R and Python tables and visualizations. It is a gene related to tumor suppression, which makes sense, for this data was taken from airway smooth muscle. I was a bit suprised with how great the difference is between this gene expression and the other genes in this dataset, for it seems to be an outlier.

# %% [markdown]
# ## Comparison between R and Python

# %% [markdown]
# ##### For this assignment, I still preferred using R. I have more familiarity with how dataframes and visualization packages work in that programming language. I wouldn't say I inherently trust one language over another. Both produced outputs I expected, and it's usually down to if you trust the programmer rather than the langugage. The R program was faster to write because I personally feel it's more intutive: setting up a virtual environment feels somewhat tedious to me, and I much prefer jumping into an R script. I needed much more help from coding agents to help me with my Python and kernels than I did for my work in R. For this reason, I would still choose R, but I do not think Python is untrustworthy or anything of the sort.
